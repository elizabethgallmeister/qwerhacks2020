# %%
import sys
assert sys.version_info >= (3, 5) # python>=3.5
import sklearn
assert sklearn.__version__ >= "0.20" # sklearn >= 0.20

import numpy as np #numerical package in python
import os
# %matplotlib inline
import matplotlib.pyplot as plt #plotting package

# to make this notebook's output identical at every run
np.random.seed(42)

#matplotlib magic for inline figures
# %matplotlib inline 
import matplotlib # plotting library
import matplotlib.pyplot as plt

# Where to save the figures
ROOT_DIR = "."

import pandas as pd

crime = pd.read_csv("Crime_Data_from_2010_to_Present.csv")

# %%
crime.info()
crime.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2110218 entries, 0 to 2110217
# Data columns (total 28 columns):
# DR_NO             int64
# Date Rptd         object
# DATE OCC          object
# TIME OCC          int64
# AREA              int64
# AREA NAME         object
# Rpt Dist No       int64
# Part 1-2          int64
# Crm Cd            int64
# Crm Cd Desc       object
# Mocodes           object
# Vict Age          int64
# Vict Sex          object
# Vict Descent      object
# Premis Cd         float64
# Premis Desc       object
# Weapon Used Cd    float64
# Weapon Desc       object
# Status            object
# Status Desc       object
# Crm Cd 1          float64
# Crm Cd 2          float64
# Crm Cd 3          float64
# Crm Cd 4          float64
# LOCATION          object
# Cross Street      object
# LAT               float64
# LON               float64
# dtypes: float64(8), int64(7), object(13)
# memory usage: 450.8+ MB
# ...

# %%
#looking for duplicate cases marked pts 1 and 2
crime.loc[crime["Date Rptd"]=="08/09/2010 12:00:00 AM"]
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 2        70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515
# 4277    100115260  08/09/2010 12:00:00 AM  08/07/2010 12:00:00 AM      1945
# 4281    100115268  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM       115
# 4282    100115269  08/09/2010 12:00:00 AM  07/29/2010 12:00:00 AM      1515
# 4284    100115272  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1200
# ...           ...                     ...                     ...       ...
# 196590  102115569  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1230
# 196591  102115570  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1430
# 196595  102115576  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      2200
# 196617  102115630  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM       505
# 208551  171318093  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      2300
#
# ...

# %%
#hist of victim age
crime["Vict Age"].hist(bins=20)
plt.show()

# %%
#get rid of irrelevant categories
updatedCrime=crime.drop(columns=['DR_NO', 'Date Rptd', 'AREA NAME', 'Rpt Dist No', 'Part 1-2', 'Crm Cd Desc', 'Mocodes', 'Premis Desc', 'Weapon Desc', 'Status Desc', 'Crm Cd 1', 'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'Cross Street', 'Weapon Used Cd'])
updatedCrime.head()
# Out:
#                  DATE OCC  TIME OCC  AREA   Crm Cd  Vict Age Vict Sex  \
# 0  02/20/2010 12:00:00 AM      1350     13     900        48        M
# 1  09/12/2010 12:00:00 AM        45     14     740         0        M
# 2  08/09/2010 12:00:00 AM      1515     13     946         0        M
# 3  01/05/2010 12:00:00 AM       150      6     900        47        F
# 4  01/02/2010 12:00:00 AM      2100      1     122        47        F
#
#   Vict Descent  Premis Cd Status                                 LOCATION  \
# 0            H      501.0     AA   300 E  GAGE                         AV
# 1            W      101.0     IC          SEPULVEDA                    BL
# 2            H      103.0     IC  1300 E  21ST                         ST
# 3            W      101.0     IC          CAHUENGA                     BL
# 4            H      103.0     IC          8TH                          ST
#
#        LAT       LON
# 0  33.9825 -118.2695
# 1  33.9599 -118.3962
# 2  34.0224 -118.2524
# ...

# %%
updatedCrime["Vict Sex"].value_counts()
# Out:
# M    972208
# F    886945
# X     54426
# H        73
# N        17
# -         1
# Name: Vict Sex, dtype: int64

# %%
updatedCrime.dropna(subset = ["Vict Sex"], inplace=True)
updatedCrime.dropna(subset = ["Vict Descent"], inplace=True)
updatedCrime.dropna(subset = list(updatedCrime), inplace=True)

updatedCrime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1913591 entries, 0 to 2110217
# Data columns (total 12 columns):
# DATE OCC        object
# TIME OCC        int64
# AREA            int64
# Crm Cd          int64
# Vict Age        int64
# Vict Sex        object
# Vict Descent    object
# Premis Cd       float64
# Status          object
# LOCATION        object
# LAT             float64
# LON             float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 189.8+ MB

# %%
#percentage of og data set remaining w/o null value cases
1913591/2110218
# Out:
# 0.9068214753167683

# %%
updatedCrime.plot(kind="scatter", x="LON", y="LAT", alpha=0.1)

# %%
#got rid of lat/long values of 0
upCrime = updatedCrime[updatedCrime.LAT != 0.0]
upCrime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1912776 entries, 0 to 2110217
# Data columns (total 12 columns):
# DATE OCC        object
# TIME OCC        int64
# AREA            int64
# Crm Cd          int64
# Vict Age        int64
# Vict Sex        object
# Vict Descent    object
# Premis Cd       float64
# Status          object
# LOCATION        object
# LAT             float64
# LON             float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 189.7+ MB

# %%
#representation w/o lat/long vals
1912776/2110218
upCrime
# Out:
#                        DATE OCC  TIME OCC  AREA   Crm Cd  Vict Age Vict Sex  \
# 0        02/20/2010 12:00:00 AM      1350     13     900        48        M
# 1        09/12/2010 12:00:00 AM        45     14     740         0        M
# 2        08/09/2010 12:00:00 AM      1515     13     946         0        M
# 3        01/05/2010 12:00:00 AM       150      6     900        47        F
# 4        01/02/2010 12:00:00 AM      2100      1     122        47        F
# ...                         ...       ...    ...     ...       ...      ...
# 2110212  02/22/2019 12:00:00 AM       840      5     627        14        F
# 2110213  03/28/2019 12:00:00 AM       400      6     648         0        X
# 2110214  08/14/2019 12:00:00 AM      1810      7     331        40        M
# 2110215  01/06/2019 12:00:00 AM      2100     20     930        46        F
# 2110217  02/01/2019 12:00:00 AM      1615      8     330        33        F
#
#         Vict Descent  Premis Cd Status  \
# ...

# %%
#attempted rape plot
spicyCrime = upCrime[upCrime["Crm Cd"] == 122]
spicyCrime.plot(kind="scatter", x = "LON", y = "LAT", alpha=0.3)

# %%
#bounds of attempted rape scatterplot
lonMin = spicyCrime["LON"].min()
lonMax=spicyCrime["LON"].max()
latMin=spicyCrime["LAT"].min()
latMax=spicyCrime["LAT"].max()
print(lonMin, lonMax,latMin,latMax)
# Out:
# -118.6427 -118.1701 33.7105 34.3226

# %%
#attempted rape on map
import matplotlib.image as mpimg

spicyCrime = upCrime[upCrime["Crm Cd"] == 122]
spicyCrime.plot(kind="scatter", x = "LON", y = "LAT", alpha=0.08)
la_image=mpimg.imread("./la.png")
plt.imshow(la_image, extent=[-118.6427 ,-118.1701 ,33.7105 ,34.3226], alpha=0.9,
           cmap=plt.get_cmap("jet"))

# %%
#attempted rape by gender
import seaborn as sns
#sns.swarmplot(x="LON", y="LAT", data=spicyCrime)
sns.lmplot( x="LON", y="LAT", data=spicyCrime, fit_reg=False, hue='Vict Sex', legend=False, palette=dict(M="#9b59b6", F="#3498db"))
plt.legend(loc='lower left')

# %%
#all crimes by descent
sns.lmplot( x="LON", y="LAT", data=upCrime, fit_reg=False, hue='Vict Descent', legend=False)
plt.legend(loc='lower left')

# %%
upCrime["Vict Descent"].value_counts()
# Out:
# H    723899
# W    508822
# B    334453
# O    202278
# X     77217
# A     50997
# K      9120
# F      2546
# C      1054
# I       945
# J       418
# P       342
# V       199
# U       190
# Z       136
# G        85
# S        31
# D        23
# L        18
# -         3
# Name: Vict Descent, dtype: int64

# %%
import statsmodels.api as sm
import matplotlib

matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'
